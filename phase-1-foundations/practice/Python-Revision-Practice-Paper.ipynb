# %% [markdown]
# # Python Revision Practice Paper
# ### Kaggle Python Course — All 7 Lessons
#
# **28 questions** covering everything from the Kaggle Python course.
#
# | Difficulty | Symbol |
# |---|---|
# | Easy | ⭐ |
# | Medium | ⭐⭐ |
# | Hard | ⭐⭐⭐ |
#
# No imports needed unless a question asks for one. Work through each question in the empty code cell below it.
#
# ---

# %% [markdown]
# ## Lesson 1 — Hello, Python
# *Syntax, variable assignment, numbers*

# %% [markdown]
# ### Q1 · Variables & Types · ⭐
#
# Create three variables:
# - `name` — your name as a string
# - `age` — your age as an integer
# - `height_m` — your height in metres as a float
#
# Then print each variable's **value** and its **type** using `type()`.

# %%
# Your answer here

# %% [markdown]
# ### Q2 · Arithmetic & Operators · ⭐
#
# Without using a calculator, write Python expressions to find:
# 1. The remainder when `847` is divided by `13` (use `%`)
# 2. `2` raised to the power `10` (use `**`)
# 3. Integer (floor) division of `99` by `7` (use `//`)
# 4. Whether `2 ** 10` equals `1024` — print a boolean

# %%
# Your answer here

# %% [markdown]
# ### Q3 · Type Conversion · ⭐⭐
#
# Predict the output **before running**, then verify:
#
# ```python
# print(type(3 / 2))
# print(type(3 // 2))
# print(int(3.9))
# print(float('3.14') + 1)
# print(str(100) + '00')
# ```
#
# Write your predictions as comments, then run the cell.

# %%
# Predictions:
# type(3 / 2)      →
# type(3 // 2)     →
# int(3.9)         →
# float('3.14') + 1 →
# str(100) + '00'  →

print(type(3 / 2))
print(type(3 // 2))
print(int(3.9))
print(float('3.14') + 1)
print(str(100) + '00')

# %% [markdown]
# ### Q4 · Swap Variables · ⭐
#
# Given `a = 5` and `b = 10`, swap their values **without using a third variable**.
#
# Verify: after the swap, `a` should be `10` and `b` should be `5`.

# %%
# Your answer here
a = 5
b = 10

# swap here

print(a, b)  # should print: 10 5

# %% [markdown]
# ---
# ## Lesson 2 — Functions and Getting Help
# *Defining functions, default arguments, docstrings, `help()`*

# %% [markdown]
# ### Q5 · Define a Function · ⭐
#
# Write a function `bmi(weight_kg, height_m)` that:
# - Calculates BMI: `weight / height²`
# - Returns the result **rounded to 1 decimal place**
#
# Test it: `bmi(70, 1.75)` should return `22.9`.

# %%
# Your answer here

# %% [markdown]
# ### Q6 · Default Arguments · ⭐⭐
#
# Write a function `greet(name, greeting='Hello', punctuation='!')` that returns a greeting string.
#
# Test all three call styles:
# ```python
# greet('Alice')                          # → 'Hello, Alice!'
# greet('Bob', greeting='Hi')             # → 'Hi, Bob!'
# greet('Carol', 'Hey', '...')            # → 'Hey, Carol...'
# ```

# %%
# Your answer here

# %% [markdown]
# ### Q7 · Docstrings & `help()` · ⭐
#
# Add a proper **docstring** to the `bmi` function from Q5. The docstring should describe:
# - What the function does
# - Each parameter
# - What it returns
#
# Then call `help(bmi)` to verify your docstring is shown correctly.

# %%
# Your answer here

# %% [markdown]
# ### Q8 · Functions Calling Functions · ⭐⭐
#
# Write two functions:
# - `celsius_to_fahrenheit(c)` — converts Celsius to Fahrenheit: `(c * 9/5) + 32`
# - `is_boiling(temp_c)` — returns `True` if the temperature in Celsius is at or above 100°
#
# Then write a third function `describe_temp(temp_c)` that returns a string like:
# - `'22°C = 71.6°F — not boiling'`
# - `'100°C = 212.0°F — boiling!'`
#
# Use the first two functions inside `describe_temp`.

# %%
# Your answer here

# %% [markdown]
# ---
# ## Lesson 3 — Booleans and Conditionals
# *Boolean operators, comparisons, `if`/`elif`/`else`, truthy/falsy*

# %% [markdown]
# ### Q9 · Boolean Operators · ⭐
#
# Predict the output of each line **before running**, then verify:
#
# ```python
# print(True and False)
# print(True or False)
# print(not True)
# print(bool(0))
# print(bool(''))
# print(bool([]))
# print(bool('False'))
# ```

# %%
# Predictions first:

print(True and False)
print(True or False)
print(not True)
print(bool(0))
print(bool(''))
print(bool([]))
print(bool('False'))

# %% [markdown]
# ### Q10 · Conditionals · ⭐
#
# Write a function `grade(score)` that returns:
# - `'A'` for score ≥ 90
# - `'B'` for score ≥ 80
# - `'C'` for score ≥ 70
# - `'D'` for score ≥ 60
# - `'F'` for anything below 60
#
# Test with scores: 95, 83, 71, 65, 42.

# %%
# Your answer here

# %% [markdown]
# ### Q11 · FizzBuzz · ⭐⭐
#
# Write a function `fizzbuzz(n)` that returns:
# - `'FizzBuzz'` if `n` is divisible by both 3 and 5
# - `'Fizz'` if divisible by 3 only
# - `'Buzz'` if divisible by 5 only
# - The number itself (as a string) otherwise
#
# Test it for all numbers 1 through 20 using a loop.

# %%
# Your answer here

# %% [markdown]
# ### Q12 · Short-Circuit Evaluation · ⭐⭐
#
# Explain what happens in each case by predicting the output:
#
# ```python
# def loud_true():
#     print('called!')
#     return True
#
# def loud_false():
#     print('called!')
#     return False
#
# result1 = False and loud_true()    # Does loud_true() get called?
# result2 = True or loud_false()     # Does loud_false() get called?
# result3 = True and loud_true()     # Does loud_true() get called?
# ```
#
# Write your prediction as comments, then verify.

# %%
def loud_true():
    print('called!')
    return True

def loud_false():
    print('called!')
    return False

# Predictions:
# result1 — loud_true() called? 
# result2 — loud_false() called? 
# result3 — loud_true() called? 

result1 = False and loud_true()
result2 = True or loud_false()
result3 = True and loud_true()

# %% [markdown]
# ---
# ## Lesson 4 — Lists
# *Indexing, slicing, mutating, list methods*

# %% [markdown]
# ### Q13 · Indexing & Slicing · ⭐
#
# Given `planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']`:
#
# 1. Get the first planet using index 0
# 2. Get the last planet using negative indexing
# 3. Get the inner planets (Mercury to Mars) using a slice
# 4. Get every other planet starting from Venus using a slice with step
# 5. Reverse the list using a slice

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

# Your answer here

# %% [markdown]
# ### Q14 · List Methods · ⭐
#
# Starting with `nums = [3, 1, 4, 1, 5, 9, 2, 6]`:
# 1. Append `5` to the end
# 2. Insert `0` at position 2
# 3. Remove the first occurrence of `1`
# 4. Pop the last element — store it in a variable and print it
# 5. Sort the list in place
# 6. Print the final list and its length

# %%
nums = [3, 1, 4, 1, 5, 9, 2, 6]

# Your answer here

# %% [markdown]
# ### Q15 · List Mutation · ⭐⭐
#
# Explain and fix the bug:
#
# ```python
# original = [1, 2, 3]
# copy = original
# copy.append(4)
# print(original)  # Prints [1, 2, 3, 4] — why?
# ```
#
# Then show **two ways** to make a true independent copy of a list.

# %%
# Explain the bug as a comment, then show two fixes

# Bug explanation:

# Fix 1:

# Fix 2:

# %% [markdown]
# ---
# ## Lesson 5 — Loops and List Comprehensions
# *`for`, `while`, `range()`, `enumerate()`, `zip()`, list comprehensions*

# %% [markdown]
# ### Q16 · `for` Loop & `range()` · ⭐
#
# 1. Print the numbers 1 to 10 inclusive using `for` and `range()`
# 2. Print the **squares** of numbers 1 to 10 on one line each
# 3. Print only numbers from 1–20 that are divisible by 3 **or** 7

# %%
# Your answer here

# %% [markdown]
# ### Q17 · `enumerate()` & `zip()` · ⭐⭐
#
# Given:
# ```python
# names = ['Alice', 'Bob', 'Carol']
# scores = [88, 92, 79]
# ```
#
# 1. Use `enumerate()` to print: `'1. Alice'`, `'2. Bob'`, `'3. Carol'` (1-indexed)
# 2. Use `zip()` to print: `'Alice scored 88'`, `'Bob scored 92'`, `'Carol scored 79'`
# 3. Use both together to print: `'1. Alice — 88 points'` etc.

# %%
names = ['Alice', 'Bob', 'Carol']
scores = [88, 92, 79]

# Your answer here

# %% [markdown]
# ### Q18 · List Comprehensions · ⭐⭐
#
# Rewrite each loop as a **list comprehension**:
#
# ```python
# # Loop 1
# squares = []
# for n in range(1, 11):
#     squares.append(n ** 2)
#
# # Loop 2
# even = []
# for n in range(1, 21):
#     if n % 2 == 0:
#         even.append(n)
#
# # Loop 3
# words = ['hello', 'world', 'python', 'is', 'fun']
# upper_long = []
# for w in words:
#     if len(w) > 3:
#         upper_long.append(w.upper())
# ```

# %%
# Your answer here
squares = 
even = 
upper_long = 

print(squares)
print(even)
print(upper_long)

# %% [markdown]
# ### Q19 · `while` Loop · ⭐⭐
#
# Write a function `collatz(n)` that:
# - If `n` is even: divide by 2
# - If `n` is odd: multiply by 3 and add 1
# - Repeat until `n` reaches 1
# - Return the **list of all values** visited (including the starting `n` and ending `1`)
#
# Test: `collatz(6)` → `[6, 3, 10, 5, 16, 8, 4, 2, 1]`

# %%
# Your answer here

# %% [markdown]
# ---
# ## Lesson 6 — Strings and Dictionaries
# *String methods, f-strings, dict operations, dict comprehensions*

# %% [markdown]
# ### Q20 · String Methods · ⭐
#
# Given `sentence = '  Hello, World! This is Python.  '`:
# 1. Strip the surrounding whitespace
# 2. Convert to lowercase
# 3. Replace `'Python'` with `'awesome'`
# 4. Split into a list of words (split on spaces, after stripping)
# 5. Count how many times the letter `'l'` appears (case-insensitive)

# %%
sentence = '  Hello, World! This is Python.  '

# Your answer here

# %% [markdown]
# ### Q21 · f-Strings · ⭐
#
# Using only f-strings (no `+` concatenation), format the following:
#
# 1. `name = 'Ritika'`, `score = 94.567` → print: `'Ritika scored 94.6 out of 100'` (1 decimal)
# 2. `items = 42` → print: `'You have 42 items'` with `42` right-aligned in a field of width 10
# 3. A multiplication table for 7: `'7 x 1 = 7'` through `'7 x 10 = 70'` using a loop

# %%
# Your answer here

# %% [markdown]
# ### Q22 · Dictionary Operations · ⭐⭐
#
# Given:
# ```python
# student = {'name': 'Alice', 'age': 22, 'grade': 'B'}
# ```
#
# 1. Access `'grade'` safely using `.get()` with a default of `'N/A'`
# 2. Add a new key `'course'` with value `'Data Science'`
# 3. Update `'grade'` to `'A'`
# 4. Remove `'age'` using `.pop()` and print the removed value
# 5. Iterate over the dict and print `'key: value'` for every pair
# 6. Check if `'name'` is in the dict and if `'score'` is not in the dict

# %%
student = {'name': 'Alice', 'age': 22, 'grade': 'B'}

# Your answer here

# %% [markdown]
# ### Q23 · Dict Comprehension · ⭐⭐
#
# Given `words = ['apple', 'banana', 'cherry', 'date', 'elderberry']`:
#
# 1. Create a dict `word_lengths` mapping each word to its length using a dict comprehension
# 2. Create a dict `long_words` containing only words with length > 5
# 3. Create a dict `word_index` mapping each word to its position in the list (0-indexed)
#
# All three as one-liners.

# %%
words = ['apple', 'banana', 'cherry', 'date', 'elderberry']

# Your answer here

# %% [markdown]
# ---
# ## Lesson 7 — Working with External Libraries
# *Imports, operator overloading, using docs*

# %% [markdown]
# ### Q24 · Import Styles · ⭐
#
# Demonstrate **three ways** to import and use `sqrt` from the `math` module:
# 1. `import math` then use `math.sqrt()`
# 2. `from math import sqrt` then use `sqrt()` directly
# 3. `from math import sqrt as sq` then use `sq()`
#
# Calculate `√144` all three ways and confirm the result is `12.0`.
#
# Then use `dir(math)` and `help(math.floor)` to explore what else is available.

# %%
# Your answer here

# %% [markdown]
# ### Q25 · `random` Module · ⭐
#
# Using the `random` module:
# 1. Generate a random integer between 1 and 100
# 2. Pick a random item from `['rock', 'paper', 'scissors']`
# 3. Shuffle the list `[1, 2, 3, 4, 5]` in place and print it
# 4. Set a random seed to `42` then generate 3 random floats — verify they're reproducible by running twice

# %%
import random

# Your answer here

# %% [markdown]
# ### Q26 · Debug the Code · ⭐⭐
#
# Each snippet has **one bug**. Fix it and explain what was wrong:
#
# ```python
# # Snippet A
# def add(a, b):
#     result = a + b
#
# print(add(3, 4))   # prints None — why?
#
# # Snippet B
# def first_last(lst):
#     return lst[0], lst[-1]
#
# first, last, middle = first_last([10, 20, 30])  # Error — why?
#
# # Snippet C
# counts = {}
# for word in ['cat', 'dog', 'cat', 'bird', 'dog', 'cat']:
#     counts[word] =+ 1   # Bug: wrong operator
#
# # Snippet D
# nums = [1, 2, 3, 4, 5]
# for i in range(len(nums)):
#     if nums[i] % 2 == 0:
#         nums.remove(nums[i])   # Bug: modifying list while iterating
# ```

# %%
# Fix A

# Fix B

# Fix C

# Fix D

# %% [markdown]
# ### Q27 · End-to-end · ⭐⭐⭐
#
# Write a function `word_frequency(text)` that:
# 1. Takes a string of text
# 2. Converts to lowercase and splits into words
# 3. Strips punctuation from each word (use `.strip('.,!?;:\'"')`)
# 4. Returns a **dictionary** mapping each unique word to how many times it appears
# 5. **Bonus**: return the top 3 most common words as a sorted list of `(word, count)` tuples
#
# Test with: `'To be or not to be, that is the question. To be is to exist.'`

# %%
# Your answer here

# %% [markdown]
# ### Q28 · Concept Check · ⭐ to ⭐⭐⭐
#
# Answer in comments — 1–2 sentences each:
#
# 1. ⭐ What is the difference between `=` and `==` in Python?
# 2. ⭐ What does it mean for a value to be "truthy" or "falsy"? Give two examples of each.
# 3. ⭐⭐ Why does `copy = original` not create an independent copy of a list?
# 4. ⭐⭐ What is short-circuit evaluation? Why does Python use it?
# 5. ⭐⭐ What is the difference between a list and a dictionary? When would you use each?
# 6. ⭐⭐⭐ What is operator overloading? Give an example of where Python uses it already (without any imports).

# %%
# 1.

# 2.

# 3.

# 4.

# 5.

# 6.

# %% [markdown]
# ---
# ## Self-Assessment
#
# | Lesson | Questions | My score |
# |--------|-----------|----------|
# | Hello, Python | Q1–Q4 | /4 |
# | Functions and Getting Help | Q5–Q8 | /4 |
# | Booleans and Conditionals | Q9–Q12 | /4 |
# | Lists | Q13–Q15 | /3 |
# | Loops and List Comprehensions | Q16–Q19 | /4 |
# | Strings and Dictionaries | Q20–Q23 | /4 |
# | Working with External Libraries | Q24–Q28 | /5 |
# | **Total** | | **/28** |
#
# **Score guide:**
# - 24–28 ✅ Strong Python foundation — continue to NumPy/Pandas
# - 18–23 🔄 Revisit the lessons where you lost points
# - < 18 ⚠️ Redo the Kaggle Python exercises before continuing
